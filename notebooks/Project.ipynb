# %% [markdown]
# # Projekat: Numerički integratori i grafovske neuronske mreže za simulaciju dinamike čestica
# **Student:** Marko Milenković, RA60/2023

# %%
import os
if(os.getcwd().split('/')[-1] == 'notebooks'):
  os.chdir('..')

import numpy as np
import torch
import matplotlib.pyplot as plt

# Proveriti instalaciju
print('PyTorch version:', torch.__version__)

# %% [markdown]
# ## 1. Definicija problema i motivacija
# *(Uneti teorijski uvod, ciljeve i motivaciju simuliranja N-body sistema gnn mrežama naspram numeričkih integratora)*

# %% [markdown]
# ## 2. Skup podataka
# *(Opisati generisanje primarnog skupa podataka korišćenjem numeričkih integratora)*

# %%
# Import from templates
from simulation import NBodySimulation, generate_dataset
# TODO: Inicijalizacija sistema, generisanje parametara i trajektorija

# %% [markdown]
# ## 3. Metodologija
# ### 3.1 Numerička simulacija
# *(Prikazati implementirane integratore: Euler, RK4, Leapfrog, Verlet)*

# %%
# Import integrators
from integrators import EulerIntegrator, RK4Integrator, LeapfrogIntegrator, VerletIntegrator
# TODO: Kreirati i uporediti integratore

# %% [markdown]
# ### 3.2 GNN Simulator
# *(Predstaviti arhitekturu Encode-Process-Decode za simuliranje fizike)*

# %%
# Import GNN components
from models import GNNSimulator
from dataset import get_dataloaders
# TODO: Inicijalizovati i istrenirati model na generisanim podacima

# %% [markdown]
# ## 4. Način evaluacije
# *(Prikazati validaciju MSE metrikama, rollout error i vizualnim upoređivanjem)*

# %%
# TODO: Prikazati animacije kretanja GNN vs Numericki i gubitak kroz vreme
