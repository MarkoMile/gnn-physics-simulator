# %% [markdown]
# # GNN Model Development
#
# This notebook develops and tests the GNN simulator architecture.

# %%
# Import libraries
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# TODO: Import custom modules
# from src.models.gnn_simulator import GNNSimulator
# from src.data.graph_utils import build_graph

# %% [markdown]
# ## 1. Graph Representation

# %%
# TODO: Explore graph representation
# - Node features (position, velocity, mass)
# - Edge features (relative position, distance)
# - Visualize graph structure

# %% [markdown]
# ## 2. Message Passing

# %%
# TODO: Test message passing layer
# - Create sample graph
# - Run through message passing
# - Visualize feature updates

# %% [markdown]
# ## 3. Full Model

# %%
# TODO: Build and test full GNN simulator
# - Initialize model
# - Forward pass on sample data
# - Check output shapes

# %% [markdown]
# ## 4. Gradient Check

# %%
# TODO: Verify gradient flow
# - Compute loss
# - Backpropagate
# - Check gradients
